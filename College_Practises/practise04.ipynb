# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
file_path='../DSD Datasets/dataset.csv'
df=pd.read_csv(file_path)
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color='red',marker='*')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
file_paths='../DSD Datasets/dataset1.csv'
d=pd.read_csv(file_paths)
d
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
p=reg.predict(d)
p
d['price']=p
#d.to_csv('C:/Users/Deep/Desktop/prediction.csv')
plt.xlabel('area',fontsize=20)
plt.ylabel('price',fontsize=20)
plt.scatter(df.area,df.price,color='red',marker='*')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
