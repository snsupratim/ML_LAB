# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics

# %%
file_path='../Personal_Datasets/Humed-x_Dataset.csv'
df=pd.read_csv(file_path)
df.head(5)
# Out:
#    Patient ID  Age  Blood Pressure  Cholesterol Levels  Heart Rate   BMI  \
# 0         101   65             130                 250          72  28.0
# 1         102   42             110                 150          76  24.0
# 2         103   58             140                 200          80  30.0
# 3         104   71             160                 220          88  32.0
# 4         105   35             120                 180          74  27.0
#
#                              Diagnosis  \
# 0  Hypertension with high cholesterol.
# 1                    Pre-hypertension.
# 2                     Type 2 Diabetes.
# 3                       Heart Failure.
# 4                          Overweight.
#
#                                       Treatment Plan   Recovery Status  \
# 0  Medication: Lisinopril (blood pressure), Stati...  Active recovery.
# 1  Lifestyle modification: Regular exercise, heal...        Recovered.
# 2  Medication: Metformin (blood sugar control). L...  Active recovery.
# 3  Medication: Digoxin (heart function), Furosemi...  Active recovery.
# 4  Lifestyle modification: Regular exercise, heal...        Recovered.
#
#         Medication Type Follow-up Requirement
# 0  Lisinopril, Statins.            Quarterly.
# 1                  N/A.           Six months.
# 2            Metformin.            Quarterly.
# 3  Digoxin, Furosemide.              Monthly.
# 4                  N/A.         Three months.

# %%
plt.scatter(df['Blood Pressure'],df['Age'])

# %%
plt.scatter(df['Cholesterol Levels'],df['Age'])

# %%
x=df[['Blood Pressure','Cholesterol Levels','Heart Rate','BMI']]
y=df['Age']

# %%
x
# Out:
#     Blood Pressure  Cholesterol Levels  Heart Rate   BMI
# 0              130                 250          72  28.0
# 1              110                 150          76  24.0
# 2              140                 200          80  30.0
# 3              160                 220          88  32.0
# 4              120                 180          74  27.0
# ..             ...                 ...         ...   ...
# 95             140                 260          85  32.0
# 96             125                 200          70  25.0
# 97             115                 180          80  24.0
# 98             120                 190          75  23.0
# 99             120                 240          80  28.0
#
# [100 rows x 4 columns]

# %%
y
# Out:
# 0     65
# 1     42
# 2     58
# 3     71
# 4     35
#       ..
# 95    45
# 96    70
# 97    55
# 98    30
# 99    45
# Name: Age, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
len(x_train)
# Out:
# 80

# %%
x_train
# Out:
#     Blood Pressure  Cholesterol Levels  Heart Rate   BMI
# 29             125                 180          80  25.0
# 73             115                 170          75  22.0
# 7              120                 200          70  25.0
# 80             125                 215          78  24.0
# 83             135                 225          85  28.0
# ..             ...                 ...         ...   ...
# 50             130                 220          85  28.0
# 92             115                 200          75  25.0
# 9              135                 150          80  28.0
# 27             100                 130          75  20.0
# 45             100                 120          60  19.0
#
# [80 rows x 4 columns]

# %%
y_train
# Out:
# 29    50
# 73    40
# 7     45
# 80    58
# 83    53
#       ..
# 50    50
# 92    55
# 9     50
# 27    28
# 45    28
# Name: Age, Length: 80, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
#from sklearn.metrics import score
clf=LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([50.60618099, 31.27670764, 49.75306823, 66.02558667, 68.72149822,
#        42.15887113, 38.46919445, 52.81565702, 61.0323023 , 55.52072091,
#        53.90034188, 47.29934929, 33.29471786, 63.63230749, 34.50479489,
#        51.27290119, 59.68213353, 51.319202  , 57.87028869, 50.4000156 ])

# %%
y_test
# Out:
# 96    70
# 86    32
# 52    45
# 42    60
# 58    70
# 31    40
# 60    52
# 46    40
# 12    60
# 75    55
# 20    50
# 10    40
# 70    30
# 89    58
# 24    35
# 13    45
# 25    68
# 19    45
# 2     58
# 63    42
# Name: Age, dtype: int64

# %%
print(x_test)
len(x_test)
# Out:
#     Blood Pressure  Cholesterol Levels  Heart Rate   BMI
# 96             125                 200          70  25.0
# 86             105                 150          70  18.0
# 52             125                 190          70  25.0
# 42             140                 250          75  32.0
# 58             145                 245          80  35.0
# 31             115                 160          70  24.0
# 60             105                 185          80  26.0
# 46             135                 210          85  28.0
# 12             135                 180          75  35.0
# 75             135                 230          85  29.0
# 20             140                 220          95  30.0
# 10             125                 160          75  27.0
# 70             110                 150          70  18.0
# 89             145                 210          75  31.0
# 24             110                 150          80  23.0
# 13             115                 220          70  28.0
# 25             140                 220          85  32.0
# 19             130                 250          90  27.0
# 2              140                 200          80  30.0
# 63             120                 220          75  27.0
# 20

# %%
r_sq=clf.score(x,y)
print(r_sq)
# Out:
# 0.6341598940070263
