# %%
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.4.2

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.2

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
df=pd.read_csv("car-price.csv")
df.head()
# Out:
#    Mileage  Age  Sell-price
# 0    91000    7       19000
# 1    26000    2       38000
# 2    74000    6       22000
# 3    38000    3       32000
# 4    59000    5       20000

# %%
x=df[['Mileage','Age']]
y=df['Sell-price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
#from sklearn.metrics import score
clf=LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([ 38265.72647729, 145077.71335049,  57612.72924989,  38379.8101657 ,
#        109015.99006763,  49255.36899476,  69519.2199891 ,  43188.03993675,
#        118632.44960972, 104207.76029658,  99399.53052553, 113824.21983867,
#         59788.67675859,  85088.9249008 ,  50172.2172165 ,  57498.64556148,
#         81425.71072831,  32426.5647961 ,  68488.28807896,  44447.13922372])

# %%
r_sq=clf.score(x,y)
print(r_sq)
# Out:
# 0.8278520267419762

# %%
import pickle

# %%
with open('model02.pkl','wb') as file:
    pickle.dump(clf,file)
